# %%
import scipy.io as sci

# %%
import matplotlib.pyplot as plt

# %%
indian_pines_path = './Datasets/IndianPines/'
data = sci.loadmat(indian_pines_path + 'Indian_pines_corrected.mat')
data_gt = sci.loadmat(indian_pines_path + 'Indian_pines_gt.mat')

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'indian_pines_corrected'])

# %% [markdown]
# North-western Indiana and consists of $145\times145$ pixels and 224 spectral reflectance bands in the wavelength range $ (0.4 \text{ to } 2.5) \cdot 10^{-6}$ meters

# %%
X = data['indian_pines_corrected']
X.shape
# Out:
# (145, 145, 200)

# %%
from preprocessing import Dataset

# %%
Images_Generator = Dataset(X)

# %%
LrHSI = Images_Generator.img_lr
LrHSI.shape
# Out:
# (36, 36, 200)

# %%
HrMSI = Images_Generator.img_msi
HrMSI.shape
# Out:
# (145, 145, 6)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(9,3))
fig.suptitle('Horizontally stacked subplots')
figsize=(10,10)
ax1.plot(figsize=(10,10))
ax1.set_title("HrHSI (Initial)")
ax1.imshow(X[:,:,2])
ax2.plot(figsize=(10,10))
ax2.set_title("LrHSI")
ax2.imshow(LrHSI[:,:,2])
ax3.plot(figsize=(10,10))
ax3.set_title("HrMSI")
ax3.imshow(HrMSI[:,:,2])

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(9,3))
fig.suptitle('Horizontally stacked subplots')
figsize=(10,10)
ax1.plot(figsize=(10,10))
ax1.set_title("HrHSI (Initial)")
ax1.imshow(HrMSI[:,:,0], cmap="gray")
ax2.plot(figsize=(10,10))
ax2.set_title("LrHSI")
ax2.imshow(HrMSI[:,:,1], cmap="gray")
ax3.plot(figsize=(10,10))
ax3.set_title("HrMSI")
ax3.imshow(HrMSI[:,:,2], cmap="gray")

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(9,3))
fig.suptitle('Horizontally stacked subplots')
figsize=(10,10)
ax1.plot(figsize=(10,10))
ax1.set_title("HrHSI (Initial)")
ax1.imshow(HrMSI[:,:,3], cmap="gray")
ax2.plot(figsize=(10,10))
ax2.set_title("LrHSI")
ax2.imshow(HrMSI[:,:,4], cmap="gray")
ax3.plot(figsize=(10,10))
ax3.set_title("HrMSI")
ax3.imshow(HrMSI[:,:,5], cmap="gray")

# %%
data_gt.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'indian_pines_gt'])
